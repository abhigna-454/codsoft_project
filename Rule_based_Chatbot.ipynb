# %%
from nltk.chat.util import Chat, reflections

# %%
pairs = [
    [
        r"(.*)Robot",
        ["hi Human, how can I help you "]
    ],
    [
        r"(.*)question",
        ["I am here for your help"]
    ],

    [
        r"(.*)developed ",
        ["Abhigna created me using Python"]
    ],
    [
        r"(.*)alive ",
        ["I am Robot, I am just a computer program."]
    ],
    [
        r"(.*)my name(.*)",
        ["Hello %2, How are you today ?",]
    ],
    [
        r"(.*)help(.*) ",
        ["I can help you ",]
    ],
    [
        r"what(.*)name?",
        ["My name is AI Robot, but you can just call me robot and I'm a chatbot .",]
    ],
    [
        r"how (.*) you ?",
        ["I'm doing very well", "i am great !"]
    ],
    [
        r"sorry (.*)",
                ["Its alright","Its OK, never mind that",]
    ],
    [
        r"i'm (.*) (good|well|okay|ok)",
        ["Nice to hear that","Alright, great !",]
    ],
    [
        r"(hi|hey|hello|hola|holla)(.*)",
        ["Hello", "Hey there",]
    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]

    ],
    [
        r"(.*)created(.*)",
        ["Abhigna created me using Python's NLTK library ","Its top secret........... ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['TamilNadu , India',]
    ],
    [
        r"(.*)raining in (.*)",
        ["Yes, rain in the past 4 days here in %2","In %2 there is a 80% chance of rain",]
    ],
    [
        r"how (.*) health (.*)",
        ["Health is very important, but I am a computer, so I don't need to worry about my health ",]
    ],
    [
        r"(.*)(sports|game|sport)(.*)",
        ["I'm a very big fan of Cricket",]
    ],
    [
        r"who (.*) (Cricketer|Batsman)?",
        ["Mahendra Singh Dhoni "]
            ],
    [
        r"quit",
        ["Bye for now. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
    [
        r"(.*)",
        ['That is nice to hear']
    ],

]

# %%
print(reflections)
# Out:
# {'i am': 'you are', 'i was': 'you were', 'i': 'you', "i'm": 'you are', "i'd": 'you would', "i've": 'you have', "i'll": 'you will', 'my': 'your', 'you are': 'I am', 'you were': 'I was', "you've": 'I have', "you'll": 'I will', 'your': 'my', 'yours': 'mine', 'you': 'me', 'me': 'you'}

# %%
chat = Chat(pairs, reflections)

# %%
print(chat)
# Out:
# <nltk.chat.util.Chat object at 0x7a364604bdc0>

# %%
chat.converse()
# Out:
# >Hello
# Hey there
# >Robot
# hi Human, how can I help you
# >developed
# That is nice to hear
# >alive
# That is nice to hear
